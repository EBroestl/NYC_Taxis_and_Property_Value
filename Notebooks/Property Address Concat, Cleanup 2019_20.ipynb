# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
bronx = pd.read_excel('../../Data/Property Data/rollingsales_bronx20-21.xlsx',header=3)
brooklyn = pd.read_excel('../../Data/Property Data/rollingsales_brooklyn20-21.xlsx',header=3)
manhattan = pd.read_excel('../../Data/Property Data/rollingsales_manhattan20-21.xlsx',header=3)
queens = pd.read_excel('../../Data/Property Data/rollingsales_queens20-21.xlsx',header=3)
statenisland = pd.read_excel('../../Data/Property Data/rollingsales_statenisland20-21.xlsx',header=3)

# %%
bronx
# Out:
# 182

# %%
full=pd.concat([bronx,brooklyn,manhattan,queens,statenisland])

# %%
full.columns = [x.replace("\n","") for x in full.columns.to_list()]

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69036 entries, 0 to 6137
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         69036 non-null  int64
#  1   NEIGHBORHOOD                    69036 non-null  object
#  2   BUILDING CLASS CATEGORY         69036 non-null  object
#  3   TAX CLASS AT PRESENT            69036 non-null  object
#  4   BLOCK                           69036 non-null  int64
#  5   LOT                             69036 non-null  int64
#  6   EASE-MENT                       69036 non-null  object
#  7   BUILDING CLASS AT PRESENT       69036 non-null  object
#  8   ADDRESS                         69036 non-null  object
#  9   APARTMENT NUMBER                69036 non-null  object
#  10  ZIP CODE                        69036 non-null  int64
#  11  RESIDENTIAL UNITS               69036 non-null  int64
# ...

# %% [markdown]
# # failed api check, ignore
# full['ZIP CODE']=full['ZIP CODE'].astype(object)
# full['ZIP CODE']=full['ZIP CODE'].astype(str)
# full['ADDRESS']=full['ADDRESS'].astype(str)
# full['address_full']=(full['ADDRESS']+", New York, NY "+full['ZIP CODE'])

# %% [markdown]
# test = full.head(10)

# %%
full_no_zero = full.loc[~(full['SALE PRICE']==0)]

# %%
full_no_zero
# Out:
#       BOROUGH               NEIGHBORHOOD  \
# 1           2  BATHGATE
# 2           2  BATHGATE
# 3           2  BATHGATE
# 6           2  BATHGATE
# 7           2  BATHGATE
# ...       ...                        ...
# 6522        5  WOODROW
# 6525        5  WOODROW
# 6526        5  WOODROW
# 6527        5  WOODROW
# 6530        5  WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 1     01  ONE FAMILY HOMES                                            1
# 2     01  ONE FAMILY HOMES                                            1
# 3     01  ONE FAMILY HOMES                                            1
# 6     02  TWO FAMILY HOMES                                            1
# 7     02  TWO FAMILY HOMES                                            1
# ...                                            ...                  ...
# 6522  02  TWO FAMILY HOMES                                            1
# ...

# %% [markdown]
# full_no_zero.to_csv('../../Data/Property Data Processed/2014 address concat.csv')

# %% [markdown]
# full_no_zero = pd.read_csv('../../Data/Property Data Processed/2014 address concat.csv',)

# %%
test_full=full_no_zero[['ZIP CODE', 'SALE PRICE']]

# %% [markdown]
# test_full['YEAR']='2015'

# %%
test_full
# Out:
#       ZIP CODE  SALE PRICE
# 1        10457         100
# 2        10457         100
# 3        10457      345752
# 6        10457      135000
# 7        10457      325000
# ...        ...         ...
# 6522     10309      522500
# 6525     10309       43000
# 6526     10309      165000
# 6527     10309      420000
# 6530     10309      420000
#
# [49302 rows x 2 columns]

# %%
test_full2 = test_full.groupby(['ZIP CODE']).mean()

# %%
test_full2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 0 to 11694
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SALE PRICE  182 non-null    float64
# dtypes: float64(1)
# memory usage: 2.8 KB

# %%
test_full2
# Out:
#             SALE PRICE
# ZIP CODE
# 0         1.679564e+06
# 10001     4.502230e+06
# 10002     6.706104e+05
# 10003     1.259420e+06
# 10004     1.404513e+06
# ...                ...
# 11436     2.768559e+05
# 11691     4.104567e+05
# 11692     4.531400e+05
# 11693     3.005187e+05
# 11694     6.828014e+05
#
# [182 rows x 1 columns]

# %% [markdown]
# test_full3=test_full2['ZIP CODE'].astype(int)

# %%
test_full2['YEAR']='2009'

# %%
test_full2
# Out:
#             SALE PRICE  YEAR
# ZIP CODE
# 0         1.679564e+06  2009
# 10001     4.502230e+06  2009
# 10002     6.706104e+05  2009
# 10003     1.259420e+06  2009
# 10004     1.404513e+06  2009
# ...                ...   ...
# 11436     2.768559e+05  2009
# 11691     4.104567e+05  2009
# 11692     4.531400e+05  2009
# 11693     3.005187e+05  2009
# 11694     6.828014e+05  2009
#
# [182 rows x 2 columns]

# %%
# Only run on sheets with dirty columns
test_full2.columns = ['_'.join(col) for col in test_full2.columns.values]

# %%
test_full2
# Out:
#             SALE PRICE  YEAR
# ZIP CODE
# 0         2.581888e+06  2015
# 10001     8.861737e+06  2015
# 10002     3.511681e+06  2015
# 10003     2.655826e+06  2015
# 10004     2.222425e+06  2015
# ...                ...   ...
# 11436     3.484724e+05  2015
# 11691     5.085674e+05  2015
# 11692     5.074007e+05  2015
# 11693     3.696392e+05  2015
# 11694     6.036088e+05  2015
#
# [184 rows x 2 columns]

# %%
test_full2.to_csv('../../Data/Property Data Processed/2009 address concat mean.csv')

# %%
test_full2
# Out:
#             SALE PRICE  YEAR
# ZIP CODE
# 0         1.679564e+06  2009
# 10001     4.502230e+06  2009
# 10002     6.706104e+05  2009
# 10003     1.259420e+06  2009
# 10004     1.404513e+06  2009
# ...                ...   ...
# 11436     2.768559e+05  2009
# 11691     4.104567e+05  2009
# 11692     4.531400e+05  2009
# 11693     3.005187e+05  2009
# 11694     6.828014e+05  2009
#
# [182 rows x 2 columns]

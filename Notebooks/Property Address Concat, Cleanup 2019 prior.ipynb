# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
# FOR XLS
bronx = pd.read_excel('../../Data/Property Data/2016_bronx.xls',header=4)
brooklyn = pd.read_excel('../../Data/Property Data/2016_brooklyn.xls',header=4)
manhattan = pd.read_excel('../../Data/Property Data/2016_manhattan.xls',header=4)
queens = pd.read_excel('../../Data/Property Data/2016_queens.xls',header=4)
statenisland = pd.read_excel('../../Data/Property Data/2016_statenisland.xls',header=4)

# %% [markdown]
# #FOR XLSX
# bronx = pd.read_excel('../../Data/Property Data/2018_bronx.xlsx',header=4)
# brooklyn = pd.read_excel('../../Data/Property Data/2018_brooklyn.xlsx',header=4)
# manhattan = pd.read_excel('../../Data/Property Data/2018_manhattan.xlsx',header=4)
# queens = pd.read_excel('../../Data/Property Data/2018_queens.xlsx',header=4)
# statenisland = pd.read_excel('../../Data/Property Data/2018_statenisland.xlsx',header=4)

# %%
bronx
# Out:
#       BOROUGH\n             NEIGHBORHOOD\n  \
# 0             2  BATHGATE
# 1             2  BATHGATE
# 2             2  BATHGATE
# 3             2  BATHGATE
# 4             2  BATHGATE
# ...         ...                        ...
# 7198          2  WOODLAWN
# 7199          2  WOODLAWN
# 7200          2  WOODLAWN
# 7201          2  WOODLAWN
# 7202          2  WOODLAWN
#
#                          BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0     01  ONE FAMILY DWELLINGS                                          1
# 1     01  ONE FAMILY DWELLINGS                                          1
# 2     01  ONE FAMILY DWELLINGS                                          1
# 3     01  ONE FAMILY DWELLINGS                                          1
# 4     01  ONE FAMILY DWELLINGS                                          1
# ...                                            ...                    ...
# 7198  10  COOPS - ELEVATOR APARTMENTS                                   2
# ...

# %%
full=pd.concat([bronx,brooklyn,manhattan,queens,statenisland])

# %%
full.columns = [x.replace("\n","") for x in full.columns.to_list()]

# %%
full
# Out:
#       BOROUGH               NEIGHBORHOOD  \
# 0           2  BATHGATE
# 1           2  BATHGATE
# 2           2  BATHGATE
# 3           2  BATHGATE
# 4           2  BATHGATE
# ...       ...                        ...
# 8624        5  WOODROW
# 8625        5  WOODROW
# 8626        5  WOODROW
# 8627        5  WOODROW
# 8628        5  WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0     01  ONE FAMILY DWELLINGS                                        1
# 1     01  ONE FAMILY DWELLINGS                                        1
# 2     01  ONE FAMILY DWELLINGS                                        1
# 3     01  ONE FAMILY DWELLINGS                                        1
# 4     01  ONE FAMILY DWELLINGS                                        1
# ...                                            ...                  ...
# 8624  05  TAX CLASS 1 VACANT LAND                                    1B
# ...

# %% [markdown]
# full['ZIP CODE']=full['ZIP CODE'].astype(object)
# full['ZIP CODE']=full['ZIP CODE'].astype(str)
# full['ADDRESS']=full['ADDRESS'].astype(str)
# full['address_full']=(full['ADDRESS']+", New York, NY "+full['ZIP CODE'])

# %% [markdown]
# test = full.head(10)

# %%
full_no_zero = full.loc[~(full['SALE PRICE']==0)]

# %%
full_no_zero
# Out:
#       BOROUGH               NEIGHBORHOOD  \
# 1           2  BATHGATE
# 2           2  BATHGATE
# 3           2  BATHGATE
# 6           2  BATHGATE
# 9           2  BATHGATE
# ...       ...                        ...
# 8623        5  WOODROW
# 8624        5  WOODROW
# 8625        5  WOODROW
# 8627        5  WOODROW
# 8628        5  WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 1     01  ONE FAMILY DWELLINGS                                        1
# 2     01  ONE FAMILY DWELLINGS                                        1
# 3     01  ONE FAMILY DWELLINGS                                        1
# 6     01  ONE FAMILY DWELLINGS                                        1
# 9     02  TWO FAMILY DWELLINGS                                        1
# ...                                            ...                  ...
# 8623  02  TWO FAMILY DWELLINGS                                        1
# ...

# %% [markdown]
# full_no_zero.to_csv('../../Data/Property Data Processed/2014 address concat.csv')

# %% [markdown]
# full_no_zero = pd.read_csv('../../Data/Property Data Processed/2014 address concat.csv',)

# %%
test_full=full_no_zero[['ZIP CODE', 'SALE PRICE']]

# %% [markdown]
# test_full['YEAR']='2019'

# %% [markdown]
# test_full

# %%
test_full2 = test_full.groupby(['ZIP CODE']).mean()

# %%
test_full2['YEAR']='2016'

# %%
test_full2
# Out:
#             SALE PRICE  YEAR
# ZIP CODE
# 0         1.806131e+06  2016
# 10001     1.240706e+07  2016
# 10002     2.948765e+06  2016
# 10003     3.269310e+06  2016
# 10004     6.719811e+06  2016
# ...                ...   ...
# 11436     3.730568e+05  2016
# 11691     5.303975e+05  2016
# 11692     4.632841e+05  2016
# 11693     4.401821e+05  2016
# 11694     6.034365e+05  2016
#
# [186 rows x 2 columns]

# %%
test_full2.to_csv('../../Data/Property Data Processed/2016 address concat mean.csv')

# %%
test_full2.columns = ['_'.join(col) for col in test_full2.columns.values]

# %%
test_full2
# Out:
#           SALE PRICE_count  SALE PRICE_mean  SALE PRICE_std  SALE PRICE_min  \
# ZIP CODE
# 0                     25.0     5.415645e+05    7.740895e+05            10.0
# 10001                252.0     1.084060e+07    3.995866e+07         28570.0
# 10002                329.0     1.848497e+06    3.688139e+06            10.0
# 10003                835.0     1.884507e+06    5.937898e+06             1.0
# 10004                115.0     9.447476e+06    5.785246e+07            10.0
# ...                    ...              ...             ...             ...
# 11436                199.0     4.886056e+05    2.918412e+06             1.0
# 11691                267.0     6.654742e+05    1.679610e+06             1.0
# 11692                118.0     4.468739e+05    2.681030e+05             1.0
# 11693                 79.0     3.709260e+05    1.041741e+06            10.0
# 11694                178.0     5.583154e+05    3.837956e+05             1.0
#
# ...

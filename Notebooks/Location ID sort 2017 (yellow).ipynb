# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../../Data/Taxi Data/yellow_17/yellow_tripdata_2017-12.csv')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2017-12-01 00:12:00   2017-12-01 00:12:51                1
# 1               1  2017-12-01 00:13:37   2017-12-01 00:13:47                1
# 2               1  2017-12-01 00:14:15   2017-12-01 00:15:05                1
# 3               1  2017-12-01 00:15:33   2017-12-01 00:15:37                1
# 4               1  2017-12-01 00:50:03   2017-12-01 00:53:35                1
# ...           ...                  ...                   ...              ...
# 9508271         1  2017-12-31 23:31:57   2017-12-31 23:55:59                1
# 9508272         2  2017-12-31 22:53:16   2017-12-31 22:57:03                1
# 9508273         2  2017-12-31 23:05:23   2017-12-31 23:14:30                1
# 9508274         2  2017-12-31 23:22:29   2017-12-31 23:31:47                1
# 9508275         2  2017-12-31 23:34:49   2017-12-31 23:40:29                1
#
# ...

# %%
df=df.reset_index()

# %% [markdown]
# df['store_and_fwd_flag'].value_counts()

# %% [markdown]
# df['RatecodeID'].value_counts()

# %%
df_start=df[['passenger_count','trip_distance','fare_amount','mta_tax','tip_amount','tolls_amount','PULocationID']]

# %%
df_start=df_start.rename(columns={"PULocationID": "LocationID"})

# %%
df_end=df[['DOLocationID']]

# %% [markdown]
# df_end

# %% [markdown]
# df_start

# %%
df_end=df.rename(columns={"DOLocationID": "LocationID"})

# %%
group_start = df_start.groupby(['LocationID']).describe()

# %%
group_start.columns = ['_'.join(col) for col in group_start.columns.values]

# %%
group_start
# Out:
#             passenger_count_count  passenger_count_mean  passenger_count_std  \
# LocationID
# 1                           732.0              1.495902             1.040222
# 2                             7.0              1.000000             0.000000
# 3                            41.0              1.878049             1.519788
# 4                         23641.0              1.627131             1.269354
# 5                             7.0              1.000000             0.577350
# ...                           ...                   ...                  ...
# 261                       62867.0              1.736619             1.316834
# 262                      115646.0              1.613977             1.270413
# 263                      180574.0              1.612043             1.263036
# 264                      173053.0              1.451191             1.039322
# 265                        4516.0              1.408769             0.963039
#
# ...

# %%
group_end = df_end.value_counts(['LocationID'])

# %%
group_end = pd.DataFrame(group_end,columns=['dropoff_count'])

# %%
merge=group_start.merge(group_end, how='left', on='LocationID')

# %%
merge.to_csv('../../Data/yellow_tripdata_2017-12-processed.csv')

# %%
merge
# Out:
#             passenger_count_count  passenger_count_mean  passenger_count_std  \
# LocationID
# 1                           732.0              1.495902             1.040222
# 2                             7.0              1.000000             0.000000
# 3                            41.0              1.878049             1.519788
# 4                         23641.0              1.627131             1.269354
# 5                             7.0              1.000000             0.577350
# ...                           ...                   ...                  ...
# 261                       62867.0              1.736619             1.316834
# 262                      115646.0              1.613977             1.270413
# 263                      180574.0              1.612043             1.263036
# 264                      173053.0              1.451191             1.039322
# 265                        4516.0              1.408769             0.963039
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../../Data/Taxi Data/yellow_16/yellow_tripdata_2016-01.csv')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2017-01-09 11:13:28   2017-01-09 11:25:45                1
# 1               1  2017-01-09 11:32:27   2017-01-09 11:36:01                1
# 2               1  2017-01-09 11:38:20   2017-01-09 11:42:05                1
# 3               1  2017-01-09 11:52:13   2017-01-09 11:57:36                1
# 4               2  2017-01-01 00:00:00   2017-01-01 00:00:00                1
# ...           ...                  ...                   ...              ...
# 9710119         2  2017-01-31 23:59:58   2017-02-01 00:20:01                1
# 9710120         2  2017-01-31 23:59:58   2017-02-01 00:03:43                1
# 9710121         1  2017-01-31 23:59:59   2017-02-01 00:24:35                2
# 9710122         2  2017-01-31 23:59:59   2017-02-01 00:21:15                1
# 9710123         2  2017-01-31 23:59:59   2017-02-01 00:07:50                3
#
# ...

# %%
df=df.reset_index()

# %% [markdown]
# df['store_and_fwd_flag'].value_counts()

# %% [markdown]
# df['RatecodeID'].value_counts()

# %%
df_start=df[['passenger_count','trip_distance','fare_amount','mta_tax','tip_amount','tolls_amount','store_and_fwd_flag']]

# %%
df_start=df_start.rename(columns={"store_and_fwd_flag": "LocationID"})

# %%
df_end=df[['RatecodeID']]

# %% [markdown]
# df_end

# %% [markdown]
# df_start

# %%
df_end=df.rename(columns={"RatecodeID": "LocationID"})

# %%
group_start = df_start.groupby(['LocationID']).describe()

# %%
group_start.columns = ['_'.join(col) for col in group_start.columns.values]

# %%
group_start
# Out:
#             passenger_count_count  passenger_count_mean  passenger_count_std  \
# LocationID
# N                       9664833.0              1.630754             1.274049
# Y                         45291.0              1.250734             0.598236
#
#             passenger_count_min  passenger_count_25%  passenger_count_50%  \
# LocationID
# N                           0.0                  1.0                  1.0
# Y                           0.0                  1.0                  1.0
#
#             passenger_count_75%  passenger_count_max  trip_distance_count  \
# LocationID
# N                           2.0                  9.0            9664833.0
# Y                           1.0                  6.0              45291.0
#
#             trip_distance_mean  ...  tip_amount_75%  tip_amount_max  \
# LocationID                      ...
# N                     2.804008  ...            2.26          999.99
# Y                     4.924502  ...            3.20           85.00
#
# ...

# %%
group_end = df_end.value_counts(['LocationID'])

# %%
group_end = pd.DataFrame(group_end,columns=['dropoff_count'])

# %%
merge=group_start.merge(group_end, how='left', on='LocationID')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\BROBRO~1\AppData\Local\Temp/ipykernel_3336/1357950905.py in <module>
# ----> 1 merge=group_start.merge(group_end, how='left', on='LocationID')
#
# ~\.conda\envs\geospatial\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9184         from pandas.core.reshape.merge import merge
#    9185
# -> 9186         return merge(
#    9187             self,
#    9188             right,
#
# ~\.conda\envs\geospatial\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
# ...

# %%
merge.to_csv('../../Data/yellow_tripdata_2016-01-processed.csv')

# %%
merge
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BROBRO~1\AppData\Local\Temp/ipykernel_3336/3666326433.py in <module>
# ----> 1 merge
#
# NameError: name 'merge' is not defined

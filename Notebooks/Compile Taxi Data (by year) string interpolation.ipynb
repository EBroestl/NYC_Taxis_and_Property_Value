# %%
import pandas as pd
import datetime as dt

# %%
year = '2018'
type = 'yellow'

# %%
m01=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-01-processed.csv')
m02=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-02-processed.csv')
m03=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-03-processed.csv')
m04=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-04-processed.csv')
m05=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-05-processed.csv')
m06=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-06-processed.csv')
m07=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-07-processed.csv')
m08=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-08-processed.csv')
m09=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-09-processed.csv')
m10=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-10-processed.csv')
m11=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-11-processed.csv')
m12=pd.read_csv(f'../../Data/Taxi Processed - Taxi Zone/{type}_{year}/{type}_tripdata_{year}-12-processed.csv')

# %%
m01['Date']=f'01/01/{year}'
m02['Date']=f'02/01/{year}'
m03['Date']=f'03/01/{year}'
m04['Date']=f'04/01/{year}'
m05['Date']=f'05/01/{year}'
m06['Date']=f'06/01/{year}'
m07['Date']=f'07/01/{year}'
m08['Date']=f'08/01/{year}'
m09['Date']=f'09/01/{year}'
m10['Date']=f'10/01/{year}'
m11['Date']=f'11/01/{year}'
m12['Date']=f'12/01/{year}'

# %%
full=pd.concat([m01,m02,m03,m04,m05,m06,m07,m08,m09,m10,m11,m12])

# %%
full['Date']= pd.to_datetime(full['Date'])

# %%
full['type']=f'{type}'

# %%
full.to_csv(f'../../Data/Taxi Processed - Taxi Zone/Year Processed/{type}_{year}-processed.csv')

# %%
check=pd.read_csv('../../Data/Taxi Processed - Taxi Zone/Year Processed/yellow_2018-processed.csv')

# %%
check
# Out:
#       Unnamed: 0  LocationID  passenger_count_count  passenger_count_mean  \
# 0              0           1                  571.0              1.523643
# 1              1           2                    4.0              1.000000
# 2              2           3                   37.0              1.324324
# 3              3           4                19656.0              1.620981
# 4              4           5                    2.0              1.500000
# ...          ...         ...                    ...                   ...
# 3127         257         261                49886.0              1.688410
# 3128         258         262               101208.0              1.580725
# 3129         259         263               163411.0              1.576809
# 3130         260         264               158648.0              1.423025
# 3131         261         265                 4327.0              1.423388
#
#       passenger_count_std  passenger_count_min  passenger_count_25%  \
# ...

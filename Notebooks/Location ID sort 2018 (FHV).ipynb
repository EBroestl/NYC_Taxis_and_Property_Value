# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../../Data/Taxi Data/FHV_18/fhv_tripdata_2018-01.csv')

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-01-01 00:18:50   2018-01-01 00:24:39
# 1              2  2018-01-01 00:30:26   2018-01-01 00:46:42
# 2              2  2018-01-01 00:07:25   2018-01-01 00:19:45
# 3              2  2018-01-01 00:32:40   2018-01-01 00:33:41
# 4              2  2018-01-01 00:32:40   2018-01-01 00:33:41
# ...          ...                  ...                   ...
# 793524         2  2018-01-31 23:42:10   2018-01-31 23:43:24
# 793525         2  2018-02-01 00:00:48   2018-02-01 00:08:11
# 793526         2  2018-01-31 23:19:43   2018-01-31 23:23:41
# 793527         2  2018-01-31 23:57:59   2018-02-01 00:01:50
# 793528         2  2018-01-31 23:30:45   2018-01-31 23:37:10
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           236           236
# 1                       N           1            43            42
# 2                       N           1            74           152
# 3                       N           1           255           255
# 4                       N           1           255           255
# ...                   ...         ...           ...           ...
# 793524                  N           1           120           243
# 793525                  N           1            41           116
# 793526                  N           1            41            42
# 793527                  N           1            42            41
# 793528                  N           1           193             7
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                     5           0.70          6.0    0.5      0.5
# 1                     5           3.50         14.5    0.5      0.5
# 2                     1           2.14         10.0    0.5      0.5
# 3                     1           0.03         -3.0   -0.5     -0.5
# 4                     1           0.03          3.0    0.5      0.5
# ...                 ...            ...          ...    ...      ...
# 793524                1           0.51          3.5    0.5      0.5
# 793525                1           1.46          7.0    0.5      0.5
# 793526                1           1.04          5.5    0.5      0.5
# 793527                1           0.91          5.5    0.5      0.5
# 793528                2           0.00          0.0    0.0      0.0
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             0.00           0.0        NaN                    0.3
# 1             0.00           0.0        NaN                    0.3
# 2             0.00           0.0        NaN                    0.3
# 3             0.00           0.0        NaN                   -0.3
# 4             0.00           0.0        NaN                    0.3
# ...            ...           ...        ...                    ...
# 793524        0.00           0.0        NaN                    0.3
# 793525        0.00           0.0        NaN                    0.3
# 793526        0.00           0.0        NaN                    0.3
# 793527        0.01           0.0        NaN                    0.3
# 793528        0.00           0.0        NaN                    0.0
#
#         total_amount  payment_type  trip_type
# 0               7.30             2        1.0
# 1              15.80             2        1.0
# 2              11.30             2        1.0
# 3              -4.30             3        1.0
# 4               4.30             2        1.0
# ...              ...           ...        ...
# 793524          4.80             2        1.0
# 793525          8.30             2        1.0
# 793526          6.80             2        1.0
# 793527          6.81             1        1.0
# 793528          0.00             2        1.0
#
# [793529 rows x 19 columns]

# %%
df_start=df[['PUlocationID']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\BROBRO~1\AppData\Local\Temp/ipykernel_19284/2864855485.py in <module>
# ----> 1 df_start=df[['PUlocationID']]
#
# ~\.conda\envs\geospatial\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~\.conda\envs\geospatial\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\.conda\envs\geospatial\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['PUlocationID'], dtype='object')] are in the [columns]"

# %%
df_end=df[['DOlocationID']]

# %%
df_start2=df_start['PUlocationID'].value_counts()

# %%
df_end2=df_end['DOlocationID'].value_counts()

# %%
group_start_df = df_start2.to_frame()

# %%
group_end_df = df_end2.to_frame()

# %%
group_start=group_start_df.rename(columns={"PUlocationID": "pickup_count_count"})

# %%
group_end=group_end_df.rename(columns={"DOlocationID": "dropoff_count"})

# %% [markdown]
# group_end['LocationID'] = group_end.index

# %%
group_start['LocationID'] = group_start.index

# %%
group_end = pd.DataFrame(group_end,columns=['dropoff_count'])

# %%
group_end['LocationID'] = group_end.index

# %%
merge=group_start.merge(group_end, how='left', on='LocationID')

# %%
merge.to_csv('../../Data/fhv_tripdata_2018-01-processed.csv')

# %% [markdown]
# read=pd.read_csv('../../Data/fhv_tripdata_2018-02-processed.csv')

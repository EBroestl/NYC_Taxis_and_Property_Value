# %%
import pandas as pd
import datetime as dt

# %%
m01=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-01-processed.csv')
m02=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-02-processed.csv')
m03=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-03-processed.csv')
m04=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-04-processed.csv')
m05=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-05-processed.csv')
m06=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-06-processed.csv')
m07=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-07-processed.csv')
m08=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-08-processed.csv')
m09=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-09-processed.csv')
m10=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-10-processed.csv')
m11=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-11-processed.csv')
m12=pd.read_csv('../../../Data/Taxi Processed - Taxi Zone/yellow_2014/yellow_tripdata_2014-12-processed.csv')

# %%
m01['Date']='01/01/2014'
m02['Date']='02/01/2014'
m03['Date']='03/01/2014'
m04['Date']='04/01/2014'
m05['Date']='05/01/2014'
m06['Date']='06/01/2014'
m07['Date']='07/01/2014'
m08['Date']='08/01/2014'
m09['Date']='09/01/2014'
m10['Date']='10/01/2014'
m11['Date']='11/01/2014'
m12['Date']='12/01/2014'

# %%
full=pd.concat([m01,m02,m03,m04,m05,m06,m07,m08,m09,m10,m11,m12])

# %%
full
# Out:
#      LocationID   passenger_count_count   passenger_count_mean  \
# 0             1                   759.0               1.399209
# 1             2                    32.0               1.312500
# 2             3                    29.0               1.965517
# 3             4                 49556.0               1.730890
# 4             5                     4.0               4.000000
# ..          ...                     ...                    ...
# 252         259                    77.0               1.779221
# 253         260                  8516.0               1.732034
# 254         261                 65126.0               1.759359
# 255         262                162873.0               1.677374
# 256         263                239771.0               1.678977
#
#       passenger_count_std   passenger_count_min   passenger_count_25%  \
# 0                0.836218                   0.0                   1.0
# ...

# %%
full['Date']= pd.to_datetime(full['Date'])

# %%
full['type']='Yellow'

# %%
full.to_csv('../../../Data/Taxi Processed - Taxi Zone/Year Processed/yellow_2014-processed.csv')
